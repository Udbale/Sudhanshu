# %% [markdown]
# <a href="https://colab.research.google.com/github/Udbale/Sudhanshu/blob/main/Data_sets_using_matplolib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,10])
y = np.array([0,100])

plt.plot(x,y)
plt.show()

# %%
plt.style.use('classic')

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,10])
y = np.array([0,100])

plt.plot(x,y)
plt.show()

# %%
x= np.linspace(0,10,100)
fig=plt.figure()
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))
fig.savefig('graph1.png')

# %%
plt.plot(x,np.sin(x-0),color='blue')
plt.plot(x,np.sin(x-1),color='g')
plt.plot(x,np.sin(x-2),color='0.75')
plt.plot(x,np.sin(x-3),color='#FFDD44')
plt.plot(x,np.sin(x-3),color=(1.0,0.2,0.3))

# %%
plt.plot(x,np.sin(x-0),color='blue',linestyle='solid')
plt.plot(x,np.sin(x-1),color='g',linestyle='dashed')
plt.plot(x,np.sin(x-2),color='0.75',linestyle='dashdot')
plt.plot(x,np.sin(x-3),color='#FFDD44',linestyle='dotted')

# %%
fig= plt.figure()
ax = plt.axes()

x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x));

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.linspace(0,10,100)
fig=plt.figure()
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))
fig.savefig('graph1.png')

# %%
plt.plot(x,np.sin(x-0),color='blue',linestyle='solid')
plt.plot(x,np.sin(x-1),color='g',linestyle='solid')
plt.plot(x,np.sin(x-2),color='0.75',linestyle='solid')
plt.plot(x,np.sin(x-3),color='#FFDD44',linestyle='dotted')

# %%
plt.plot(x,np.sin(x-0),color='blue',linestyle='-')
plt.plot(x,np.sin(x-1),color='blue',linestyle='--')
plt.plot(x,np.sin(x-2),color='blue',linestyle='-.')
plt.plot(x,np.sin(x-3),color='blue',linestyle=':')

# %%
x = [1, 2, 3, 4, 5]  # x-axis values (time)
y = [10, 15, 7, 12, 9]  # y-axis values (dependent variable)


#create a line chart
plt.plot(x, y, marker='o')



plt.title("Line Chart Example")
plt.xlabel('Time')
plt.ylabel("Dependent Variable")
# display the chart
plt.show()

# %%
fig =plt.figure()
ax =plt.axes()

x =np.linspace(0,10,1000)
ax.plot(x,np.sin(x),label ='sin')
ax.plot(x,np.cos(x),label ='cos')
ax.set_title('multiple lines')
ax.set_xlabel('x label')
ax.set_ylabel('y label')
ax.legend()
#ax.legend(loc=1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data = {'Apple': 10, 'Orange': 15, 'Lemon': 5, 'Lime': 20}
names = list(data.keys())
values = list(data.values())

fig = plt.figure()
ax = plt.axes()
# ax.grid(linestyle='--', color='0.85')  #color: grayscle between 0 and 1

ax.bar(names, values);

# %%
data = {'Apple': 10, 'Orange': 15, 'Lemon': 5, 'Lime': 20}
names = list(data.keys())
values = list(data.values())

fig = plt.figure(figsize=(4,3))
ax = plt.axes()

ax.bar(names,values,color='teal', width =0.35);
ax.set_xlabel('fruit')
ax.set_ylabel('quantity')
ax.set_title('fruit quantities');

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.DataFrame([['A', 10, 20, 10, 30], ['B', 20, 25, 15, 25],  ['c', 12, 15, 19, 6],
        ['D',10, 29, 13, 19]],
                  columns=['Team', 'Round 1', 'Round 2', 'Round 3', 'Round 4'])
print(df)

df.plot(x='Team',    #plot grouped bar chart
kind='bar',stacked=False,title='Grouped Bar Graph With dataframe')
# Out:
#   Team  Round 1  Round 2  Round 3  Round 4
# 0    A       10       20       10       30
# 1    B       20       25       15       25
# 2    c       12       15       19        6
# 3    D       10       29       13       19
# <Axes: title={'center': 'Grouped Bar Graph With dataframe'}, xlabel='Team'>

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25,25,15])
mylabels = ["SIC", "AM", "EDS", "DT"]

plt.pie(y, labels = mylabels)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('/content/purchase_data (2).csv')
x_column_index = 0
y_column_index = 2
plt.plot(df.iloc[:,x_column_index],df.iloc[:,y_column_index])

plt.title('Line Graph')
plt.xlabel('Product')
plt.ylabel('Price Each')
# Out:
# Text(0, 0.5, 'Price Each')

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('/content/company1 - company1.csv')
x_column_index = 0
y_column_index = 4
plt.plot(df.iloc[:,x_column_index],df.iloc[:,y_column_index])

plt.title('hist')
plt.xlabel('experiNewce_level')
plt.ylabel('salary Rs')
# Out:
# Text(0, 0.5, 'salary Rs')
